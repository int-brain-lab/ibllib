# %%
## Init
from oneibl.one import ONE
from ibllib.misc import pprint
myone = ONE() # need to instantiate the class to have the API.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-387f0bc1116a> in <module>()
#       1 ## Init
# ----> 2 from oneibl.one import ONE
#       3 from ibllib.misc import pprint
#       4 myone = ONE() # need to instantiate the class to have the API.
#
# ~\Anaconda3\lib\site-packages\ibllib-0.1.2-py3.6.egg\oneibl\one.py in <module>()
#       4 import ibllib.webclient as wc
#       5 from ibllib.misc import is_uuid_string, pprint
# ----> 6 from one import OneAbstract
#       7 import oneibl.params as par
#       8
#
# ModuleNotFoundError: No module named 'one'

# %%
## In this case we just lookup the session using the date
eid, ses = myone.search(users='olivier', date_range=['2018-08-24', '2018-08-24'])
pprint(ses)

# %%
## And then load a couple of datasets
data = myone.load(eid[0], dataset_types=['clusters.peakChannel'])
